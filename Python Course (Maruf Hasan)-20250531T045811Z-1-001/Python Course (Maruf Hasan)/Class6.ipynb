# %%
str1="Hello"
str2="Shitol"
str3=str1+' '+str2
print(str3)
# Out:
# Hello Shitol

# %%
st1="123"
st2=2
num=int(st1)+st2
print(num)
# Out:
# 125

# %%
fruit='Banana'
letter= fruit[2]
print(letter)
# Out:
# n

# %%
fruit='banana'
x=3
w=fruit[x-1]
print(w)
# Out:
# n

# %%
name='Maruf Hasan'
print(len(name))
# Out:
# 11

# %%
name='My Name Is Maruf Hasan'
i=0
while i<(len(name)):
  print(name[i])
  i=i+1
# Out:
# M
# y
#
# N
# a
# m
# e
#
# I
# s
#
# M
# a
# r
# u
# f
#
# H
# a
# s
# a
# n

# %%
name='My Name Is Maruf Hasan'
for char in name:
  print(char)
# Out:
# M
# y
#
# N
# a
# m
# e
#
# I
# s
#
# M
# a
# r
# u
# f
#
# H
# a
# s
# a
# n

# %%
name='My Name Is Maruf Hasan'
for i in range(len(name)):
  print(name[i])
# Out:
# M
# y
#
# N
# a
# m
# e
#
# I
# s
#
# M
# a
# r
# u
# f
#
# H
# a
# s
# a
# n

# %%
def f_vouwel():
 name='My Name Is Maruf Hasan'
 vouwel = 'aeiou'
 new=''
 for char in name:
   if char.lower() in vouwel:
     print(vouwel)
     new = new+char
 print(new)
f_vouwel()
# Out:
# aeiou
# aeiou
# aeiou
# aeiou
# aeiou
# aeiou
# aeiou
# aeIauaa

# %%
name = 'My name is maruf hasan'
print(name[2:5])
# Out:
#  na

# %%
def panildrom(num):


  num=str(num)
  pan= str(num)[::-1]
  if pan == num:
    print("The Word Is Panildrom")
  else:
    print("Not Panildrome")
panildrom(122)
# Out:
# Not Panildrome

# %%
fruit='banana'
print('nana' in fruit)
# Out:
# True

# %%
word='banana'
if word=='banana':
  print('All right, Bananas')
if word<'banana':
  print('Your Word '+ word + ' comes before banana')
elif word>'banana':
  print('Your Word '+ word+ '  comes after banana')
else:
  print('all right,bananas')
# Out:
# All right, Bananas
# all right,bananas

# %%
name='Maruf Hasan'
l=name.lower()
w=name.center(20,'*')
s=name.endswith(('ma','an'))
print(l)
print(type(name))
print(name.capitalize())
print(w)
print(s)
# Out:
# maruf hasan
# <class 'str'>
# Maruf hasan
# ****Maruf Hasan*****
# True

# %%
def up():
  word=str(input("Enter Your Sentence: "))
  u=word.upper()
  print("Total Number of Charachter in the word is: ",len(word))
  print("The Word In uppercase: ",u)
up()
# Out:
# Enter Your Sentence: my name is maruf hasan
# Total Number of Charachter in the word is:  22
# The Word In uppercase:  MY NAME IS MARUF HASAN

# %%
def ip():
  inp=input("Enter Your Number: ")
  for char in inp:
    if char.isalpha():
      print("Invalid Input")
    elif char.isdigit():
       print("Its a number")
ip()
# Out:
# Enter Your Number: e
# Invalid Input

# %%
text ='maruf hasan'
st= text.split()
print(st)
js=" ".join(st)
print(js)
A=[1,2,3,4,5]
at="".join(map(str, A))
print("".join(str(C) for C in(A) ))
print(at)
# Out:
# ['maruf', 'hasan']
# maruf hasan
# 12345
# 12345

# %%
def checkname():
  name=input("Enter The Word With a: ")
  if name.startswith('a'):
    print('Word Is OK')
  else:
    print('Please Start The Word With Letter a')
checkname()
# Out:
# Enter The Word With a: pineapple
# Please Start The Word With Letter a

# %%
def checkname():
  name=input("Enter a name which end with n: ")
  if name.endswith('n'):
    print("Name Is OK")
  else:
    print("Please! sFinish Your Name with n")
checkname()
# Out:
# Enter a name which end with n: hitol
# Please! Finish Your Name with n

# %%
def index_num():
  name=input("")
# Out:
#   File "<ipython-input-137-fcb96759555d>", line 1
#     def index_num():
#                     ^
# SyntaxError: incomplete input
