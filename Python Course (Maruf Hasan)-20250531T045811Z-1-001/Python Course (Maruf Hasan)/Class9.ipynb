# %%
firstname= str(input("Enter First Name: "))
lastname = str(input("enter Last Name: "))
print(firstname," "+lastname)
# Out:
# Enter First Name: Maruf
# enter Last Name: Hasan
# Maruf  Hasan

# %%
num1= float(input("Enter The First Number: "))
num2= float(input("Enter The Second Number: "))
sum=num1+num2
diff= num1-num2
mul=num1*num2
div=num1/num2
print("Sum of Numbers: ",sum,"Difference of Number: ",diff,"Product of number: ",mul,"Quotient of Numbers: ",div)
# Out:
# Enter The First Number: 5
# Enter The Second Number: 2.5
# Sum of Numbers:  7.5 Difference of Number:  2.5 Product of number:  12.5 Quotient of Numbers:  2.0

# %%
def area(l,w):
 a=l*w
 print("Area Of The Rectangle is : " ,a )
area(6,5)
# Out:
# Area Of The Rectangle is :  30

# %%
def length():
  st = str(input("Enter The Word"))
  l=len(st)
  print(l)
length()
# Out:
# Enter The WordHello
# 5

# %%
def li():
  li=[1,2,3,4,5,6]
  print(li[1],li[3])
li()
# Out:
# 2 4

# %%
number= str(input("Enter The Number: "))
n=int(number)
sq= n*n
print(sq)
# Out:
# Enter The Number: 5
# 25

# %%
name=str(input("Enter Your Name: "))
age=input("Enter Yout Age: ")
print("Hello My Name Is ",name," and My Age Is",age,"years Old")
# Out:
# Enter Your Name: Maruf Hasan
# Enter Yout Age: 24
# Hello My Name Is  Maruf Hasan  and My Age Is 24 years Old

# %%
import builtins
nu=[1,4,2,5,7]
print("Maximum Number is : " ,max(nu))
print("Maximum Number is : " ,min(nu))
print("Maximum Number is : " ,builtins.sum(nu))
# Out:
# Maximum Number is :  7
# Maximum Number is :  1
# Maximum Number is :  19

# %%
def check():
  n=int(input("Enter The Number: "))
  if n%3==0 and n%5==0:
    print("The Number is Divisable By 3 and 5")
  else:
    print("The Number is not Divisable By 3 and 5")
check()
# Out:
# Enter The Number: 10
# The Number is not Divisable By 3 and 5

# %%
def su():
  sum=0
  for i in range(5):
    n=int(input(f'Enter The {i+1} Number: '))
    sum=sum+n
  print("The Sum Of The Number Is: ",sum)

su()
# Out:
# Enter The 1 Number: 5
# Enter The 2 Number: 6
# Enter The 3 Number: 9
# Enter The 4 Number: 5
# Enter The 5 Number: 25
# The Sum Of The Number Is:  50

# %%
count=0
c=0

while True:
  n=int(input("Enter The Number: "))
  if n==0:
    break
  if n%2==0:
    count += 1
  else:
    c+=1

print(count)
print(c)
# Out:
# Enter The Number: 4
# Enter The Number: 5
# Enter The Number: 8
# Enter The Number: 9
# Enter The Number: 2
# Enter The Number: 0
# 3
# 2

# %%
n=int(input("Enter The Number: "))
fact=1
for i in range(1,n+1):
  fact =fact*i

print(fact)
# Out:
# Enter The Number: 5
# 120

# %%
def math():
  n=int(input("Enter The Number: "))
  mul=1
  for i in range(n+1):
     n=n
  for j in range(1,13):
     mul=i*j
     print(i,"X", j,"=",mul)
math()
# Out:
# Enter The Number: 5
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
# 5 X 10 = 50
# 5 X 11 = 55
# 5 X 12 = 60

# %%
max=0
while True:
  num=int(input("Enter The Number: "))
  if num == -1:
    break
  for i in range(num+1):
   if i>max:
    max=i
print(max)
# Out:
# Enter The Number: 65
# Enter The Number: 756
# Enter The Number: 89
# Enter The Number: 654
# Enter The Number: -1
# 3

# %%
n=int(input("Enter Number: "))
for i in range(2,int(n*0.5)+1):
  if n%i==0:
    print("The Number is not prime")
    break
  else:
    print("The Number is prime")
    break
# Out:
# Enter Number: 675678
# The Number is not prime

# %%
 n=int(input("Enter The Student Number: "))
 sub=int(input("How Many Subject You Have: "))
 avg=0
 total=0

 for i in range(n):
  s=input("Enter The Student Name: ")
  for j in range(sub):
    su=(input("Enter Your Subject Name: "))
    suu=int(input("Enter Subject Number: "))
     total += 1
  print(total)
# Out:
# Enter The Student Number: 1
# How Many Subject You Have: 4
# Enter The Student Name: Maruf
# Enter Your Subject Name: Bangla
# Enter Subject Number: 100
# Enter Your Subject Name: English
# Enter Subject Number: 50
# Enter Your Subject Name: Math
# Enter Subject Number: 70
# Enter Your Subject Name: Religion
# Enter Subject Number: 100
# 4
