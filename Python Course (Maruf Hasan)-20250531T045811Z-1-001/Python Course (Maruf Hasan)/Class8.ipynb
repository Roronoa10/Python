# %%
dict_=dict()
dict_['abc']=34
dict_['xyz']={1:23,2:56}
dict_[3]=[2,3,5]
print (dict_)
print(dict_['xyz'][2])
print(dict_[3][2])
for item in dict_.values():
  print(item)
# Out:
# {'abc': 34, 'xyz': {1: 23, 2: 56}, 3: [2, 3, 5]}
# 56
# 5
# 34
# {1: 23, 2: 56}
# [2, 3, 5]

# %%
dict_ = dict()
dict_ ['name']='alice'
dict_['age'] = 'age'
dict_['city']='New York'
print(dict_['name'])
# Out:
# alice

# %%
dict_ = dict()
dict_ ['job']='Engineer'
dict_['city']='San Francisco'

print(dict_['job'])
# Out:
# Engineer

# %%
dict_ = dict()
dict_ ['name']='alice'
dict_['age'] = 'age'
dict_['city']='New York'
if 'age' in dict_:
  print('Age Exist')
else:
  print('age not exist')
# Out:
# Age Exist

# %%
from random import randint
print(randint(1,10))
# Out:
# 2

# %%
import time
start_time=time.time()
print(time.time())
for i in range(1000000):
  i +=1
end_time = time.time()
print(end_time-start_time)
# Out:
# 1732532663.342313
# 0.14957332611083984

# %%
from random import randit
listlen = 100000
list_of_number = listlen*[0]
dict_of_numbers= dict()

# %%
dict_ = dict()
dict_['Maruf']=50
dict_['Hasan']=80
dict_['Shitol']=90
dict_['Nur']=100
dict_['Tasnim']=75

for key,value in dict_.items():
  print(key,value)
# Out:
# Maruf 50
# Hasan 80
# Shitol 90
# Nur 100
# Tasnim 75

# %%
product = {
    'laptop' : 10000,
    'smart phone' :5000,
    'smart watch' :3400,
    'tab': 12345,
    'smart tv' :50000
}
sum=0
for value in product.values():
  sum += value
print(sum)
# Out:
# 80745

# %%
list_of_word = "My name is Aisha. I’m in 9th grade at a school here in Chittagong. I always try my best in everything I do, and I like to encourage my friends to do the same. They know they can count on me for help. I do well in both my classes and sports. Even when things get tough, I can handle the pressure. My teachers appreciate my good manners and how I’m always on time. I never seem to get tired because my parents are always there for me, making sure I get enough rest and eat healthy foods.Thanks to all my hard work, I always get good grades. I even get a scholarship for being a high achiever! I learned a lot about computers in school, and I feel confident using them. I like to have a clear plan for everything I do, a schedule that helps me get things done at home and school. Of course, I always listen to my parents and help out at home. I help Mom with the laundry and dishes, and Dad with his work projects sometimes too.At home, I share some of the chores, like helping with laundry and washing dishes. I keep my room clean and even decorate it a little every Sunday. I know what’s expected of me, both for myself and for my family. I like to make people laugh with my jokes and have friendly conversations with my classmates. If they’re going through a tough time, I’m always there with advice and support. I try to be kind to everyone, especially the elderly and children in my neighborhood."
wordcount= dict()
for w in (list_of_word.split(' ')):
  if w in wordcount:
      wordcount[w] += 1
  else:
    wordcount[w] = 1
print(wordcount)
# Out:
# {'My': 2, 'name': 1, 'is': 1, 'Aisha.': 1, 'I’m': 3, 'in': 6, '9th': 1, 'grade': 1, 'at': 3, 'a': 8, 'school': 1, 'here': 1, 'Chittagong.': 1, 'I': 20, 'always': 6, 'try': 2, 'my': 12, 'best': 1, 'everything': 2, 'do,': 2, 'and': 15, 'like': 4, 'to': 9, 'encourage': 1, 'friends': 1, 'do': 2, 'the': 5, 'same.': 1, 'They': 1, 'know': 2, 'they': 1, 'can': 2, 'count': 1, 'on': 2, 'me': 2, 'for': 6, 'help.': 1, 'well': 1, 'both': 2, 'classes': 1, 'sports.': 1, 'Even': 1, 'when': 1, 'things': 2, 'get': 6, 'tough,': 1, 'handle': 1, 'pressure.': 1, 'teachers': 1, 'appreciate': 1, 'good': 2, 'manners': 1, 'how': 1, 'time.': 1, 'never': 1, 'seem': 1, 'tired': 1, 'because': 1, 'parents': 2, 'are': 1, 'there': 2, 'me,': 2, 'making': 1, 'sure': 1, 'enough': 1, 'rest': 1, 'eat': 1, 'healthy': 1, 'foods.Thanks': 1, 'all': 1, 'hard': 1, 'work,': 1, 'grades.': 1, 'even': 2, 'scholarship': 1, 'being': 1, 'high': 1, 'achiever!': 1, 'learned': 1, 'lot': 1, 'about': 1, 'computers': 1, 'school,': 1, 'feel
# ...

# %%
dirt={ 'a':4,'b':1,'c':6,'d':2,'e':3}
new_dirt={k:v*5 for (k,v) in dirt.items()}
new2={k:v for (k,v) in dirt.items() if 'a' in k}
new3={k:('even' if v % 2 == 0 else 'odd')for (k,v) in dirt.items()}
print(new_dirt)
print(new2)
print(new3)
# Out:
# {'a': 20, 'b': 5, 'c': 30, 'd': 10, 'e': 15}
# {'a': 4}
# {'a': 'even', 'b': 'odd', 'c': 'even', 'd': 'even', 'e': 'odd'}

# %%
word=['shitol','Maruf','nur','tasnim','Mustakim']
new={name:len(name) for name in word}
print(new)
# Out:
# {'shitol': 6, 'Maruf': 5, 'nur': 3, 'tasnim': 6, 'Mustakim': 8}

# %%
word=['shitol','Maruf','nur','tasnim','Mustakim']
new={name:len(name) for name in word if len(name) > 5}
print(new)
# Out:
# {'shitol': 6, 'tasnim': 6, 'Mustakim': 8}

# %%
word=['shitol','Maruf','nur','tasnim','Mustakim']

# %%
col= {
    'Green':9872,
    'Red':6278,
    'Yellow': 8291,
    'Black': 5362,
    'White': 2315
}
for color,value in col.items():
  color=color.upper()

  print(f'{color}:{value}')
# Out:
# GREEN:9872
# RED:6278
# YELLOW:8291
# BLACK:5362
# WHITE:2315

# %%
num={
    'one': 1,
    'two':2,
    'three':3,
    'four':4
}
new={k:v for (k,v) in num.items() if v%2==0}

print(new)
print
# Out:
# {'two': 2, 'four': 4}

# %%
num={
    'one': 1,
    'two':2,
    'three':3,
    'four':4
}
multi={k:v*2 for (k,v) in num.items()}
print(multi)
# Out:
# {'one': 2, 'two': 4, 'three': 6, 'four': 8}
