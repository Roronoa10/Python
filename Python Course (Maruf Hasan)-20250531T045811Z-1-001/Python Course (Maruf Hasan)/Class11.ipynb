# %%
with open(filename,'r') as file:
  content = file.read
  print(content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-1cc58e463f19> in <cell line: 2>()
#       1 filename= 'n.txt'
# ----> 2 with open(filename,'r') as file:
#       3   content = file.read
#       4   print(content)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'n.txt'
